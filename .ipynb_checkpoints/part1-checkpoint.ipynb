# %% [markdown]
# # 前処理

# %%
import codecs
import pandas as pd

train= pd.read_csv('train+.csv', sep=',',engine='c')

test=pd.read_csv('test+.csv', sep=',',engine='c')

train=train.drop(['Unnamed: 0'],axis=1)
test=test.drop(['Unnamed: 0'],axis=1)

# %%
len(train)
# Out:
# 31470

# %%
#型
print('train '+'-'*50)
print(train.dtypes)
print('test '+'-'*50)
print(test.dtypes)
# Out:
# train --------------------------------------------------
# id          int64
# 賃料          int64
# 所在地        object
# アクセス       object
# 間取り        object
# 築年数        object
# 方角         object
# 面積         object
# 所在階        object
# バス・トイレ     object
# キッチン       object
# 放送・通信      object
# 室内設備       object
# 駐車場        object
# 周辺環境       object
# 建物構造       object
# 契約期間       object
# lat       float64
# lng       float64
# dtype: object
# test --------------------------------------------------
# id          int64
# 所在地        object
# アクセス       object
# 間取り        object
# 築年数        object
# 方角         object
# 面積         object
# 所在階        object
# バス・トイレ     object
# キッチン       object
# 放送・通信      object
# 室内設備       object
# 駐車場        object
# 周辺環境       object
# 建物構造       object
# 契約期間       object
# lat       float64
# lng       float64
# dtype: object

# %%
print('train '+'-'*50)
print(train.isnull().sum())
print('test '+'-'*50)
print(test.isnull().sum())
# Out:
# train --------------------------------------------------
# id           0
# 賃料           0
# 所在地          0
# アクセス         0
# 間取り          0
# 築年数          0
# 方角        2749
# 面積           0
# 所在階          0
# バス・トイレ     329
# キッチン       621
# 放送・通信     3440
# 室内設備        82
# 駐車場       5287
# 周辺環境      9432
# 建物構造         0
# 契約期間      7120
# lat          0
# lng          0
# dtype: int64
# test --------------------------------------------------
# id           0
# 所在地          0
# アクセス         0
# 間取り          0
# 築年数          0
# 方角        2808
# 面積           0
# 所在階          1
# バス・トイレ     320
# キッチン       635
# 放送・通信     3454
# 室内設備        73
# 駐車場       5356
# 周辺環境      9241
# 建物構造         0
# 契約期間      6981
# lat          0
# lng          0
# dtype: int64

# %%
train_tmp = train.copy()
test_tmp = test.copy()
train_tmp = train_tmp.drop("賃料", axis=1)
df = pd.concat([train_tmp, test_tmp])
df=df.reset_index(drop=True)

len(df)
# Out:
# 62732

# %%
df=df.rename(columns={'所在地':'address','アクセス':'access','間取り':'space','面積':'width','放送・通信':'information','築年数':'years','方角':'direction', '所在階':'bfloor','バス・トイレ':'bath','キッチン':'kitchen','室内設備':'service','駐車場':'parking','周辺環境':'enviroment','建物構造':'architect','契約期間':'period','lat':'lat','lng':'lng'})
df
# Out:
#           id             address  \
# 0          1         東京都北区滝野川３丁目
# 1          2         東京都中央区月島３丁目
# 2          3         東京都渋谷区笹塚２丁目
# 3          4   東京都杉並区高円寺南２丁目23-2
# 4          5      東京都葛飾区金町３丁目7-2
# 5          6        東京都荒川区南千住５丁目
# 6          7        東京都練馬区東大泉３丁目
# 7          8         東京都目黒区鷹番１丁目
# 8          9         東京都文京区向丘１丁目
# 9         10         東京都板橋区板橋４丁目
# 10        11    東京都大田区西馬込１丁目30-8
# 11        12       東京都江戸川区北小岩３丁目
# 12        13         東京都港区南青山６丁目
# 13        14    東京都杉並区阿佐谷南３丁目６－５
# 62720  東急東横線\t祐天寺駅\t徒歩11分\t\t東急東横線\t学芸大学駅\t徒歩15分\t\t東...   1DK   14年5ヶ月
# 62721  丸ノ内線(池袋－荻窪)\t新中野駅\t徒歩3分\t\t中央線（快速）\t中野(東京都)駅\t...   2DK   31年5ヶ月
# 62722  東西線\t神楽坂駅\t徒歩4分\t\t有楽町線\t江戸川橋駅\t徒歩9分\t\t都営大江戸線...    1K    0年3ヶ月
# 62723  総武線・中央線（各停）\t錦糸町駅\t徒歩9分\t\t半蔵門線\t錦糸町駅\t徒歩9分\t\...  1LDK    0年2ヶ月
# 62724  京急本線\t六郷土手駅\t徒歩6分\t\t京急大師線\t港町駅\t徒歩13分\t\t京急本線...  1LDK    0年9ヶ月
# 62725  丸ノ内線(池袋－荻窪)\t新中野駅\t徒歩4分\t\t中央線（快速）\t中野(東京都)駅\t...    1K   2年11ヶ月
# 62726  東急東横線\t多摩川駅\t徒歩10分\t\t東急池上線\t雪が谷大塚駅\t徒歩9分\t\t東...  2LDK    7年5ヶ月
# 62727  埼京線\t板橋駅\t徒歩3分\t\t都営三田線\t新板橋駅\t徒歩9分\t\t東武東上線\t...    1K    0年1ヶ月
# 62728  都営新宿線\t岩本町駅\t徒歩2分\t\t山手線\t秋葉原駅\t徒歩4分\t\t日比谷線\t...    1R   15年6ヶ月
# 62729  都営大江戸線\t新江古田駅\t徒歩10分\t\t西武池袋線\t江古田駅\t徒歩20分\t\t...  1LDK    1年0ヶ月
# 62730  有楽町線\t麹町駅\t徒歩3分\t\t丸ノ内線(池袋－荻窪)\t四ツ谷駅\t徒歩4分\t\t...    1K   15年4ヶ月
# 62731  都営浅草線\t西馬込駅\t徒歩8分\t\t東急池上線\t池上駅\t徒歩19分\t\t都営浅草...    1K   16年3ヶ月
#
#       direction    width    bfloor  \
# 0            南東  20.01m2   1階／12階建
# 1           NaN   16.5m2   5階／10階建
# 2             南  22.05m2  12階／15階建
# 3             南  60.48m2    3階／4階建
# 4             南  39.66m2    1階／2階建
# 5             東   50.8m2   6階／12階建
# 6             南  23.82m2    6階／8階建
# 7           NaN  32.32m2    1階／6階建
# 8            北西  65.59m2    4階／9階建
# 9            南東   30.3m2    2階／3階建
# 10            西  25.81m2    1階／6階建
# 11          NaN   23.1m2    1階／2階建
# 12            北  37.53m2   6階／10階建
# 13            東   41.5m2    3階／3階建
# 14            西  17.73m2   4階／11階建
# 15           南西  32.84m2    4階／5階建
# 16            西  25.93m2    2階／5階建
# 17           南東  25.82m2    1階／2階建
# 18          NaN  70.82m2   5階／11階建
# 19           南西  57.71m2   8階／12階建
# 20            南  59.62m2       2階建
# 21           南西  21.06m2   7階／10階建
# 22           北西   81.2m2  10階／42階建
# 23            東  22.98m2    4階／5階建
# 24            北  15.48m2    2階／4階建
# 25           南東   11.7m2    1階／2階建
# 26            南   41.6m2  12階／12階建
# 27            西     14m2    2階／2階建
# 28           南西  46.21m2  10階／10階建
# 29            東  31.21m2   1階／10階建
# ...         ...      ...       ...
# 62702         南  25.86m2    4階／9階建
# 62703        南東  35.62m2    2階／2階建
# 62704        南東  24.13m2   2階／11階建
# 62705        北東  27.98m2   9階／14階建
# 62706         北  26.51m2   9階／11階建
# 62707         南  55.31m2    5階／6階建
# 62708         南   53.5m2    1階／2階建
# 62709         西  27.37m2    4階／8階建
# 62710       NaN     42m2    3階／3階建
# 62711       NaN  29.87m2    5階／6階建
# 62712         西     26m2    4階／5階建
# 62713         南  44.62m2    1階／2階建
# 62714        南西     25m2    2階／5階建
# 62715       NaN   30.3m2  10階／14階建
# 62716         南  58.09m2    6階／8階建
# 62717         西   18.9m2    2階／2階建
# 62718         南  20.03m2    1階／2階建
# 62719         西  28.38m2    2階／6階建
# 62720         東  30.67m2    3階／5階建
# 62721         東  46.85m2    4階／5階建
# 62722         北  25.73m2  13階／14階建
# 62723         東  40.85m2   9階／13階建
# 62724         南  37.45m2    3階／5階建
# 62725         南  29.81m2    3階／3階建
# 62726         南  66.37m2       2階建
# 62727         東  25.66m2    6階／8階建
# 62728         南  22.71m2   8階／15階建
# 62729        南東  45.76m2  10階／14階建
# 62730         北   55.2m2  14階／14階建
# 62731         南  21.18m2    5階／5階建
#
#                                                     bath  \
# 0       専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座
# 1                                  専用トイレ／\tシャワー／\t温水洗浄便座
# 2      専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
# 3         専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t温水洗浄便座／\t洗面台独立
# 4                   専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能
# 5      専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
# 6      専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# 7      専用バス／\t専用トイレ／\tバス・トイレ別／\t追焚機能／\t浴室乾燥機\t／\t温水洗浄...
# 8                  専用バス／\t専用トイレ／\tバス・トイレ別／\t追焚機能／\t洗面台独立
# 9                  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t洗面台独立
# 10     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# 11                                                 専用トイレ
# 12     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# 13                                 バス・トイレ別／\tシャワー／\t追焚機能
# 14                                                  シャワー
# 15           専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t洗面台独立／\t脱衣所
# 16       バス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座／\t洗面台独立／\t脱衣所
# 17      専用バス／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座／\t洗面台独立
# 18     専用バス／\t専用トイレ／\tバス・トイレ別／\t追焚機能／\t浴室乾燥機\t／\t温水洗浄...
# 19           専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t洗面台独立／\t脱衣所
# 20     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t洗面台独立／\...
# 21                         専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー
# 22     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# 23           専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t洗面台独立／\t脱衣所
# 24                                           専用バス／\tシャワー
# 25                専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t温水洗浄便座
# 26     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
# 27                                                  シャワー
# 28                         シャワー／\t追焚機能／\t浴室乾燥機\t／\t洗面台独立
# 29     専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# ...                                                  ...
# 62702                     専用バス／\t専用トイレ／\tバス・トイレ別／\t浴室乾燥機
# 62703  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
# 62704                専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t脱衣所
# 62705                  バス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座
# 62706  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
# 62707                             バス・トイレ別／\tシャワー／\t洗面台独立
# 62708             バス・トイレ別／\tシャワー／\t追焚機能／\t温水洗浄便座／\t洗面台独立
# 62709              専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t洗面台独立
# 62710                                     バス・トイレ別／\tシャワー
# 62711      専用バス／\t専用トイレ／\tバス・トイレ別／\t温水洗浄便座／\t洗面台独立／\t脱衣所
# 62712                                専用バス／\t専用トイレ／\tシャワー
# 62713                      バス・トイレ別／\tシャワー／\t追焚機能／\t洗面台独立
# 62714  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄...
#
ズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場\t公営水道／\t下水...
# 62711  エアコン付\tウォークインクローゼット\tシューズボックス／\tバルコニー／\tフローリング...
# 62712  エアコン付\tバルコニー／\tフローリング／\t室内洗濯機置場／\tタイル張り\t公営水道／...
# 62713           エアコン付\tシューズボックス／\tフローリング／\t室内洗濯機置場\t都市ガス
# 62714  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...
# 62715  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\t敷...
# 62716  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...
# 62717   エアコン付\tシューズボックス／\t出窓／\t室内洗濯機置場\t公営水道／\t下水／\t都市ガス
# 62718                      エアコン付\tフローリング／\t室内洗濯機置場\t都市ガス
# 62719  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...
# 62720  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t2面採光／\t室内洗濯...
# 62721  エアコン付\tシューズボックス／\tバルコニー／\t室内洗濯機置場／\tエレベーター\t公営...
# 62722     エアコン付\tバルコニー／\tフローリング／\t室内洗濯機置場／\tエレベーター\t都市ガス
# 62723  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...
# 62724  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...
# 62725         エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場
# 62726  冷房／\tエアコン付\t床下収納\tシューズボックス／\tバルコニー／\tフローリング／\t...
# 62727  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\t敷...
# 62728  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...
# 62729  エアコン付／\t床暖房\tフローリング／\t室内洗濯機置場／\t敷地内ごみ置き場\t／\tエ...
# 62730  冷房／\tエアコン付／\t床暖房\tバルコニー／\tフローリング／\t24時間換気システム\...
# 62731  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\tエ...
#
#                                                  parking  \
# 0                                                駐輪場\t空有
# 1                             駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# 2      駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t30,000円(税込)\t距離100m
# 3                              駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 4        駐車場\t近隣\t17,000円(税込)\t距離300m\t駐輪場\t無\tバイク置き場\t無
# 5       駐輪場\t空有\t駐車場\t近隣\t27,000円(税込)\t距離150m\tバイク置き場\t無
# 6       駐輪場\t空有\t駐車場\t近隣\t16,000円(税込)\t距離200m\tバイク置き場\t無
# 7                                                    NaN
# 8                                                 駐車場\t無
# 9                                                 駐車場\t無
# 10             駐車場\t空有\t32,400円(税込)\t駐輪場\t空有\tバイク置き場\t空有
# 11                                                   NaN
# 12                                                   NaN
# 13                                     駐輪場\t無\tバイク置き場\t無
# 14                                    駐輪場\t空有\tバイク置き場\t無
# 15       駐車場\t近隣\t27,000円(税込)\t距離500m\t駐輪場\t無\tバイク置き場\t無
# 16         駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t23,000円\t距離150m
# 17                              駐車場\t近隣\t15,120円\t距離200m
# 18                                               駐輪場\t空有
# 19                             駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 20              駐車場\t空有\t0円\t駐輪場\t空有\t0円\tバイク置き場\t空有\t0円
# 21                                               駐輪場\t空有
# 22                                               駐輪場\t空有
# 23      駐輪場\t空有\t駐車場\t近隣\t25,000円(税込)\t距離100m\tバイク置き場\t無
# 24                   駐車場\t空有(1台)\t10,000円\t距離0m\t(小型車のみ)
# 25                                           駐輪場\t空有\t0円
# 26      駐輪場\t空有\t駐車場\t近隣\t37,800円(税込)\t距離300m\tバイク置き場\t無
# 27                                    駐輪場\t空有\tバイク置き場\t無
# 28                                     駐輪場\t無\tバイク置き場\t無
# 29                            駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# ...                                                  ...
# 62702                                                NaN
# 62703   駐輪場\t空有\t駐車場\t近隣\t35,000円(税込)\t距離300m\tバイク置き場\t無
# 62704           駐車場\t空有\t35,000円(税込)\t駐輪場\t空有\tバイク置き場\t無
# 62705                                             駐車場\t無
# 62706  駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t12,960円(税込)\t距離300m
# 62707                                駐輪場\t空有\tバイク置き場\t空有
# 62708                         駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# 62709                        駐輪場\t空有\tバイク置き場\t空有\t駐車場\t無
# 62710       駐輪場\t空有\t駐車場\t近隣\t20,000円\t距離250m\tバイク置き場\t無
# 62711                                            駐輪場\t空有
# 62712                                                NaN
# 62713      駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t13,000円\t距離200m
# 62714                                                NaN
# 62715                                                NaN
# 62716                  駐輪場\t空有\t駐車場\t近隣\t28,000円\t距離150m
# 62717                                  駐輪場\t無\tバイク置き場\t無
# 62718                                                NaN
# 62719   駐輪場\t空有\t駐車場\t近隣\t21,600円(税込)\t距離300m\tバイク置き場\t無
# 62720   駐輪場\t空有\t駐車場\t近隣\t37,800円(税込)\t距離300m\tバイク置き場\t無
# 62721                                            駐輪場\t空有
# 62722                                             駐車場\t無
# 62723                                            駐輪場\t空有
# 62724                           駐車場\t近隣\t30,000円\t距離400m
# 62725                                                NaN
# 62726                           駐車場\t近隣\t30,000円\t距離400m
# 62727                          駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 62728                          駐車場\t空有\t43,200円\t駐輪場\t空有
# 62729           駐車場\t空有\t32,400円(税込)\t駐輪場\t空有\tバイク置き場\t無
# 62730                                            駐輪場\t空有
# 62731                                                NaN
#
#                                               enviroment        architect  \
# 0      【小学校】 495m\t【大学】 461m\t【小学校】 962m\t【公園】 1103m\...     RC（鉄筋コンクリート）
# 1                                           【スーパー】 1283m              鉄骨造
# 2      【スーパー】 89m\t【コンビニ】 184m\t【コンビニ】 392m\t【スーパー】 492m     RC（鉄筋コンクリート）
# 3      【スーパー】 225m\t【スーパー】 448m\t【スーパー】 619m\t【スーパー】 ...     RC（鉄筋コンクリート）
# 4      【スーパー】 193m\t【スーパー】 298m\t【スーパー】 660m\t【スーパー】 ...               木造
# 5                               【スーパー】 251m\t【コンビニ】 376m     RC（鉄筋コンクリート）
# 6      【スーパー】 812m\t【コンビニ】 149m\t【コンビニ】 942m\t【スーパー】 ...     RC（鉄筋コンクリート）
# 7      【スーパー】 334m\t【スーパー】 562m\t【スーパー】 694m\t【コンビニ】 ...     RC（鉄筋コンクリート）
# 8                                                    NaN  SRC（鉄骨鉄筋コンクリート）
# 9                                                    NaN              鉄骨造
# 10     【スーパー】 406m\t【スーパー】 406m\t【スーパー】 483m\t【コンビニ】 ...     RC（鉄筋コンクリート）
# 11                                                   NaN               木造
# 12                                                   NaN     RC（鉄筋コンクリート）
# 13                                                   NaN     RC（鉄筋コンクリート）
# 62707                     2年間  35.704000  139.785977
# 62708                     2年間  35.742963  139.588665
# 62709                     2年間  35.722605  139.690328
# 62710                     2年間  35.662068  139.877127
# 62711                     2年間  35.614495  139.675186
# 62712                     NaN  35.728309  139.748598
# 62713                     2年間  35.755359  139.872006
# 62714                     2年間  35.641836  139.644595
# 62715                     2年間  35.681340  139.687102
# 62716                     2年間  35.747163  139.709823
# 62717                     2年間  35.653300  139.654156
# 62718                     NaN  35.741634  139.703263
# 62719                     2年間  35.750103  139.850248
# 62720                     NaN  35.638697  139.683262
# 62721                     2年間  35.696428  139.664979
# 62722                     2年間  35.705371  139.728959
# 62723                     NaN  35.700316  139.809101
# 62724                     NaN  35.538432  139.710285
# 62725                     NaN  35.696428  139.664979
# 62726                     NaN  35.589682  139.671996
# 62727                     2年間  35.742059  139.718584
# 62728                     NaN  35.693369  139.777349
# 62729  2年間\t※この物件は\t定期借家\tです。  35.728150  139.667420
# 62730                     NaN  35.686153  139.736463
# 62731                     NaN  35.583678  139.707093
#
# [62732 rows x 18 columns]

# %%
def filter_period(x):
    try :
        if "定期借家" in x:
            return 1
        else :
            return 0
    except TypeError:
        return 0
    

rp=df.period.map(filter_period)

# %%
# train[train.賃料>1000000]

# %%
#アクセス時間の前処理
access=df.access.str.split("\t\t",expand=True)
# access.isnull().sum()
# access[0]

# %%
access.columns=['access0','access1','access2','access3']

# %%
station=access.access0.map(lambda x:x.split("\t")[1])

# %%
access=access.applymap(lambda x:x.split("歩") if x is not None else None)
def filter_func1(x):
    try:
        return int(x[1].replace("分",""))
    except IndexError:
        return None
    except TypeError:
        return None
    except ValueError:
        return None
access=access.applymap(filter_func1)

# %%
accessmiss=access[access.access0.isnull()].index
df.access[access.access0.isnull()]
# Out:
# 1372     常磐線\t金町(東京都)駅\t/バス(15分)ふれあいの家下車\t\t京成金町線\t京成金町...
# 9845             東急田園都市線\t桜新町駅\t/バス(1分)深沢小学校前　　徒歩１分下車徒歩10分
# 12581    山手線\t日暮里駅\t車3km(15分)\t\t千代田線\t町屋(東京メトロ)駅\t徒歩8分...
# 13507    常磐線\t金町(東京都)駅\t/バス(15分)西水元２丁目下車\t\t常磐線\t亀有駅\t徒...
# 30995    常磐線\t金町(東京都)駅\t/バス(7分)水元4丁目下車\t\t京成金町線\t京成金町駅\...
# 31282    常磐線\t金町(東京都)駅\t/バス(9分)ふれあいの家下車\t\t京成金町線\t京成金町駅...
# 34224    常磐線\t金町(東京都)駅\t車3.1km(10分)\t\t常磐線\t亀有駅\t/バス(24...
# 37603    千代田線\t北綾瀬駅\t車3.9km(11分)\t\t常磐線\t亀有駅\t/バス(19分)西...
# 38790    常磐線\t金町(東京都)駅\t/バス(8分)水元公園下車\t\t京成金町線\t京成金町駅\t...
# 46965    常磐線\t金町(東京都)駅\t/バス(10分)バス下車\t\t京成金町線\t京成金町駅\t/...
# 56577                西武池袋線\t大泉学園駅\t/バス(13分)長久保　停歩5分下車徒歩35分
# 56906    常磐線\t金町(東京都)駅\t/バス(8分)水元公園下車\t\t京成金町線\t京成金町駅\t...
# 57023    常磐線\t金町(東京都)駅\t/バス(8分)水元4丁目下車\t\t京成金町線\t京成金町駅\...
# Name: access, dtype: object

# %%
access.access0.ix[accessmiss]=[15,1,15,15,7,9,10,11,8,10,13,8,8]

# %%
access.isnull().sum()
# Out:
# access0        0
# access1     3030
# access2     6701
# access3    62255
# dtype: int64

# %%
# del access["access3"]

access=access.fillna(method='ffill',axis='columns')
access=access.fillna(method='bfill',axis='columns')

# access[access.access0.isnull()].index

# %%
df[df.index==9845]
access[access.index==9845]=1

# %%
df[df.index==56577]
access[access.index==56577]=13

# %%
#住所の前処理
address=df.address

# %%
address=address.map(lambda x :x.replace("東京都",""))

# %%
address1=address.map(lambda x:x.split("区")[0])

# %%
address2=address.map(lambda x:x.split("区")[1])

# %%
#前処理
import re    
address2=address2.map(lambda x:re.split("１|２|３|４|５|６|７|８|９|1|2|3|4|5|6|7|8|9|一丁目|二丁目|三丁目|四丁目|五丁目|六丁目|七丁目|八丁目",x)[0] )

# %%
#築年数の前処理
years=df.years
years.map(lambda x:str(x.split("年")[0]))
def filter_func2(x):
    kari=x.split("年")[0]
    if kari=="新築":
        return 0
    else :
        return int(kari)
years=years.map(filter_func2)

# %%
space=df.space

# %%
#間取りの前処理
import re
df["room"]=0
df["R"]=0
df["L"]=0
df["D"]=0
df["K"]=0
df["S"]=0
df.room=df.space.apply(lambda x: int(re.split("L|D|K|S|R",x)[0]))
df.R=df.space.apply(lambda x: 1 if "R" in x else 0)
df.L=df.space.apply(lambda x: 1 if "L" in x else 0)
df.D=df.space.apply(lambda x: 1 if "D" in x else 0)
df.K=df.space.apply(lambda x: 1 if "K" in x else 0)
df.S=df.space.apply(lambda x: 1 if "S" in x else 0)

room=df.space.apply(lambda x: re.split("L|D|K|S|R",x)[0])
R=df.space.apply(lambda x: 1 if "R" in x else 0)
L=df.space.apply(lambda x: 1 if "L" in x else 0)
D=df.space.apply(lambda x: 1 if "D" in x else 0)
K=df.space.apply(lambda x: 1 if "K" in x else 0)
S=df.space.apply(lambda x: 1 if "S" in x else 0)
room=room.apply(lambda x:int(x))

# %%
bfloor=df.bfloor
# access=df.access.str.split("\t\t",expand=True)
# bfloor=bfloor.map(lambda x:x.split("／") if type(x) is str else "3階")
# for i in bfloor:
#     if "／" not in i:
#         print(i)

# %%
import numpy as np
bfloor1=bfloor.map(lambda x: x.split("／")[0] if type(x) is str else "2階")
def floor_func(x):
    try :
        return x.split("／")[1]
    except IndexError:
        return x.split("／")[0]
    except AttributeError:
        return "2階"
bfloor2=bfloor.map(floor_func)
# for i in bfloor:
#     if "地下"  in i:
#         print(i)

bfloor1=bfloor1.map(lambda x:x.replace("地下","-"))
bfloor2=bfloor2.map(lambda x:x.replace("地下","-"))

bfloor1=bfloor1.map(lambda x:x.split("階")[0])
bfloor2=bfloor2.map(lambda x:x.split("階")[0])

# %%
# bfloor1
# j=0
# for i in bfloor1:

#     if i=="":
#         print(j)
#     j+=1

# %%
bfloor = pd.concat([bfloor1, bfloor2], axis=1)

# %%
bfloor.columns=["bfloor","height"]

# %%
#前処理
bfloor.bfloor[bfloor.bfloor==""]=None
bfloor=bfloor.fillna(method='ffill',axis='columns')
bfloor=bfloor.fillna(method='bfill',axis='columns')

# %%
bfloor=bfloor.applymap(lambda x:int(x))
bfloor1=bfloor.bfloor
bfloor2=bfloor.height

# %%
# bfloor

# %%
#面積の前処理
width=df.width

# %%
width=width.map(lambda x:float(x.replace("m2","")))

# %%
#前処理
# width

# %%
architect=df.architect

# %%
# architect.unique()

# %%
#前処理
architect=architect.map(lambda x: 0 if "木造" in x else 1)

# %%
direction=df.direction

# %%
direction=direction.fillna(method='ffill')

# %%
#前処理
direction=direction.map(lambda x:1if "南" in x else 0)

# %%
bath=df.bath.str.split("／\t",expand=True)

# %%
bath.columns=["bath0","bath1","bath2","bath3","bath4","bath5","bath6","bath7","bath8"]

# %%
# bath.bath0.unique()

# %%
# bath.bath1.unique()

# %%
# bath.bath2.unique()

# %%
# bath.bath3.unique()

# %%
bath=df.bath

# %%
def filter_toilet(x):
    try :
        if '共同トイレ' in x :
            return 1
        else:
            return 0
    except TypeError:
        return 0

sharetoilet=bath.map(filter_toilet)

# %%
#前処理
# sharetoilet

# %%
def filter_bath(x):
    try :
        if 'バス・トイレ別' in x :
            return 1
        else:
            return 0
    except TypeError:
        return 1
separatebath=bath.map(filter_bath)

# %%
#前処理
# separatebath

# %%
kitchen=df.kitchen.str.split("／\t",expand=True)

# %%
# kitchen

# %%
kitchen.columns=["kitchen0","kitchen1","kitchen2","kitchen3","kitchen4","kitchen5","kitchen6","kitchen"]

# %%
def filter_ih(x):
    try :
        if 'IHコンロ' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
ih=df.kitchen.map(filter_ih)
# ih

# %%
def filter_gas(x):
    try :
        if 'ガス' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
gas=df.kitchen.map(filter_gas)

# %%
# df.service.str.split("／\t",expand=True)

# %%
# df['室内設備'].unique()
def filter_ms(x):
    try:
        if x.count("階")==2:
            return 1
        else:
            return 0
    except AttributeError:
        return 1
#前処理
ms=df.bfloor.map(filter_ms)
# ms

# %% [markdown]
# 室内洗濯機置場
# バルコニー
# フローリング
# エアコン付

# %%
def filter_wm(x):
    try :
        if '室内洗濯機置場' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
wm=df.service.map(filter_wm)

# %%
def filter_pa(x):
    try:
        if '空有' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理

pa=df.parking.map(filter_pa)
# df.parking.head()
# pa

# %%
# pa.head()

# %%
#前処理
new=df.years.map(lambda x :1if x=="新築" else 0)

# %%
one=bfloor1.map(lambda x:1 if x==1 else 0)
# one
#前処理

# %%
def filter_air(x):
    try :
        if 'エアコン' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
air=df.service.map(filter_air)

# %%
def filter_flooring(x):
    try :
        if 'フローリング' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
flooring=df.service.map(filter_flooring)

# %%
def filter_loft(x):
    try :
        if 'ロフト' in x:
            return 1
        else:
            return 0
    except TypeError:
        return 0
#前処理
loft=df.service.map(filter_loft)

# %%
nullcol=df.isnull().any(axis=1).map(lambda x:1 if x==True else 0)

# %%
# access
# address1
# years
# room
# L
# D
# K
# S
# bfloor1
# bfloor2
# width
# architect
# direction
# sharetoilet
# separatebath
# ih
# gas
# wm
# pa
# ms
# # address=pd.get_dummies(address1)
# pa

# %%
# df_tofile=pd.concat([df.id,access.access0,address1,years,room,L,D,K,S,bfloor1,bfloor2,width,architect,direction,sharetoilet,separatebath,ih,gas,wm,pa,ms], axis=1)
# df_tofile=pd.merge(df_tofile, train[["id","賃料"]], how='outer', on='id')
# df_tofile.columns=["id","access","address","years","room","L","D","K","S","bfloor","height","width","architect","direction","sharetoilet","separatebath","ih","gas","wm","pa","ms","value"]
# # df_tofile=df_tofile.drop(["L","D","ih"],axis=1)
# df_tofile=df_tofile.drop("id",axis=1)

# %%
df_tofile=pd.concat([df.id,access.access0,address1,years,df.lat,df.lng,room,L,D,K,S,bfloor1,bfloor2,width,architect,direction,sharetoilet,ih,gas,wm,pa,ms,one,air,rp], axis=1)
df_tofile=pd.merge(df_tofile, train[["id","賃料"]], how='outer', on='id')
df_tofile.columns=["id","access0","address1","years","lat","lng","room","L","D","K","S","bfloor","height","width","architect","direction","sharetoilet","ih","gas","wm","pa","ms","one","air","rp","value"]
# df_tofile=df_tofile.drop(["L","D","ih"],axis=1)
df_tofile=df_tofile.drop("id",axis=1)
# df_tofile=df_tofile.drop(df_tofile.index[30539])
df_tofile=df_tofile.drop(df_tofile.index[20926])
# df_tofile=df_tofile.drop(df_tofile.index[20643])
df_tofile=df_tofile.drop(df_tofile.index[5775])
# df_tofile=df_tofile.drop(df_tofile.index[5093])

# %%
# df_tofile.to_csv('alldata.csv', sep = '\t',encoding='utf-16')

# %% [markdown]
# # データ分析

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/Users/ogatatakuya/.matplotlib/matplotlibrc'

# %%
import matplotlib as mpl
mpl.get_configdir()
# Out:
# '/Users/ogatatakuya/.matplotlib'

# %%
import matplotlib as mpl
mpl.font_manager._rebuild()

# %%
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = 'IPAexGothic'

# plt.figure(figsize=(20, 10))

# %%
df=df_tofile

# %%
df.address1.value_counts().plot(kind="bar",color="blue")

# %%
sns.boxplot(x="address1", y="value", data=df);

# %%
sns.boxplot(x="address1", y="value", data=df[df.value<400000]);

# %%
# sns.boxplot(x="address", y="value", data=df[(df["room"]==2) & (df["value"]<=400000)])

# %%
sns.scatterplot(x="width", y="value", data=df.dropna());

# %%
# sns.scatterplot(x="width",y="value",data=df)
df[(df.width<30)&(df.value>1000000)]
# Out:
# Empty DataFrame
# Columns: [access0, address1, years, lat, lng, room, L, D, K, S, bfloor, height, width, architect, direction, sharetoilet, ih, gas, wm, pa, ms, one, air, rp, value]
# Index: []
#
# [0 rows x 25 columns]

# %%
# import seaborn as sns
# sns.set_style("darkgrid")

# #3次元プロットするためのモジュール
# from mpl_toolkits.mplot3d import Axes3D

# #グラフの枠を作っていく
# fig = plt.figure()
# ax = Axes3D(fig)

# #軸にラベルを付けたいときは書く
# ax.set_xlabel("X")
# ax.set_ylabel("Y")
# ax.set_zlabel("Z")

# #.plotで描画
# #linestyle='None'にしないと初期値では線が引かれるが、3次元の散布図だと大抵ジャマになる
# #markerは無難に丸
# ax.plot(df.lat,df.lng,df.value,marker="o",linestyle='None',ms=1)

# #最後に.show()を書いてグラフ表示

# %%
df.plot(kind='scatter', x='lat', y='lng', c=df.value,cmap="tab20" ,s=0.1)

# %% [markdown]
# # 機械学習

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split, GridSearchCV



X = df_tofile.dropna().drop("value",axis=1)

# %%
test=df_tofile[df_tofile.isnull().any(axis=1)]

# %%
X.corr()[X.corr()<-0.2]
# Out:
#               access0     years  lat  lng      room   L   D   K   S    bfloor  \
# access0           NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# years             NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# lat               NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# lng               NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# room              NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# L                 NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# D                 NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# K                 NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# S                 NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# bfloor            NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# height      -0.223539       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# width             NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# architect         NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# direction         NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# sharetoilet       NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# ih                NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# gas               NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# wm                NaN -0.352648  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# pa                NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# ms                NaN       NaN  NaN  NaN -0.219674 NaN NaN NaN NaN       NaN
# one               NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN -0.363285
# air               NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
# rp                NaN       NaN  NaN  NaN       NaN NaN NaN NaN NaN       NaN
#
#             ...  direction  sharetoilet        ih       gas        wm  pa  \
# access0     ...        NaN          NaN       NaN       NaN       NaN NaN
# years       ...        NaN          NaN       NaN       NaN -0.352648 NaN
# lat         ...        NaN          NaN       NaN       NaN       NaN NaN
# lng         ...        NaN          NaN       NaN       NaN       NaN NaN
# room        ...        NaN          NaN       NaN       NaN       NaN NaN
# L           ...        NaN          NaN       NaN       NaN       NaN NaN
# D           ...        NaN          NaN       NaN       NaN       NaN NaN
# K           ...        NaN          NaN       NaN       NaN       NaN NaN
# S           ...        NaN          NaN       NaN       NaN       NaN NaN
# bfloor      ...        NaN          NaN       NaN       NaN       NaN NaN
# height      ...        NaN          NaN       NaN       NaN       NaN NaN
# width       ...        NaN          NaN       NaN       NaN       NaN NaN
# architect   ...        NaN          NaN       NaN       NaN       NaN NaN
# direction   ...        NaN          NaN       NaN       NaN       NaN NaN
# sharetoilet ...        NaN          NaN       NaN       NaN       NaN NaN
# ih          ...        NaN          NaN       NaN -0.524827       NaN NaN
# gas         ...        NaN          NaN -0.524827       NaN       NaN NaN
# wm          ...        NaN          NaN       NaN       NaN       NaN NaN
# pa          ...        NaN          NaN       NaN       NaN       NaN NaN
# ms          ...        NaN          NaN       NaN       NaN       NaN NaN
# one         ...        NaN          NaN       NaN       NaN       NaN NaN
# air         ...        NaN          NaN       NaN       NaN       NaN NaN
# rp          ...        NaN          NaN       NaN       NaN       NaN NaN
#
#                    ms       one  air  rp
# access0           NaN       NaN  NaN NaN
# years             NaN       NaN  NaN NaN
# lat               NaN       NaN  NaN NaN
# lng               NaN       NaN  NaN NaN
# room        -0.219674       NaN  NaN NaN
# L                 NaN       NaN  NaN NaN
# D                 NaN       NaN  NaN NaN
# K                 NaN       NaN  NaN NaN
# S                 NaN       NaN  NaN NaN
# bfloor            NaN -0.363285  NaN NaN
# height            NaN -0.273463  NaN NaN
# width       -0.309260       NaN  NaN NaN
# architect         NaN -0.258844  NaN NaN
# direction         NaN       NaN  NaN NaN
# sharetoilet       NaN       NaN  NaN NaN
# ih                NaN       NaN  NaN NaN
# gas               NaN       NaN  NaN NaN
# wm                NaN       NaN  NaN NaN
# pa                NaN       NaN  NaN NaN
# ms                NaN       NaN  NaN NaN
# one               NaN       NaN  NaN NaN
# air               NaN       NaN  NaN NaN
# rp                NaN       NaN  NaN NaN
#
# [23 rows x 23 columns]

# %%
X.corr()[X.corr()>0.5]
# Out:
#              access0  years  lat  lng      room         L         D    K    S  \
# access0          1.0    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# years            NaN    1.0  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# lat              NaN    NaN  1.0  NaN       NaN       NaN       NaN  NaN  NaN
# lng              NaN    NaN  NaN  1.0       NaN       NaN       NaN  NaN  NaN
# room             NaN    NaN  NaN  NaN  1.000000       NaN       NaN  NaN  NaN
# L                NaN    NaN  NaN  NaN       NaN  1.000000  0.741265  NaN  NaN
# D                NaN    NaN  NaN  NaN       NaN  0.741265  1.000000  NaN  NaN
# K                NaN    NaN  NaN  NaN       NaN       NaN       NaN  1.0  NaN
# S                NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  1.0
# bfloor           NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# height           NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# width            NaN    NaN  NaN  NaN  0.722496  0.687226  0.691272  NaN  NaN
# architect        NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# direction        NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# sharetoilet      NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# ih               NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# gas              NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# wm               NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# pa               NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# ms               NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# one              NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# air              NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
# rp               NaN    NaN  NaN  NaN       NaN       NaN       NaN  NaN  NaN
#
#                bfloor ...   direction  sharetoilet   ih  gas   wm   pa   ms  \
# access0           NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# years             NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# lat               NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# lng               NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# room              NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# L                 NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# D                 NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# K                 NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# S                 NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# bfloor       1.000000 ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# height       0.775313 ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# width             NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# architect         NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# direction         NaN ...         1.0          NaN  NaN  NaN  NaN  NaN  NaN
# sharetoilet       NaN ...         NaN          1.0  NaN  NaN  NaN  NaN  NaN
# ih                NaN ...         NaN          NaN  1.0  NaN  NaN  NaN  NaN
# gas               NaN ...         NaN          NaN  NaN  1.0  NaN  NaN  NaN
# wm                NaN ...         NaN          NaN  NaN  NaN  1.0  NaN  NaN
# pa                NaN ...         NaN          NaN  NaN  NaN  NaN  1.0  NaN
# ms                NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  1.0
# one               NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# air               NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
# rp                NaN ...         NaN          NaN  NaN  NaN  NaN  NaN  NaN
#
#              one  air   rp
# access0      NaN  NaN  NaN
# years        NaN  NaN  NaN
# lat          NaN  NaN  NaN
# lng          NaN  NaN  NaN
# room         NaN  NaN  NaN
# L            NaN  NaN  NaN
# D            NaN  NaN  NaN
# K            NaN  NaN  NaN
# S            NaN  NaN  NaN
# bfloor       NaN  NaN  NaN
# height       NaN  NaN  NaN
# width        NaN  NaN  NaN
# architect    NaN  NaN  NaN
# direction    NaN  NaN  NaN
# sharetoilet  NaN  NaN  NaN
# ih           NaN  NaN  NaN
# gas          NaN  NaN  NaN
# wm           NaN  NaN  NaN
# pa           NaN  NaN  NaN
# ms           NaN  NaN  NaN
# one          1.0  NaN  NaN
# air          NaN  1.0  NaN
# rp           NaN  NaN  1.0
#
# [23 rows x 23 columns]

# %%
X = pd.get_dummies(X)

#　目的変数に家賃単価を代入する
y = df_tofile.dropna().value
train_X, test_X,train_y, test_y = train_test_split(X,y,test_size=0.2)

# from sklearn.preprocessing import MinMaxScaler
# mmsc = MinMaxScaler()
# # 訓練用のデータを正規化する
# train_X_norm = mmsc.fit_transform(train_X)
# # 訓練用データを基準にテストデータも正規化
# test_X_norm = mmsc.transform(test_X)

# %% [markdown]
# # 重回帰分析

# %%
#重回帰分析
import sklearn
from sklearn.linear_model import LinearRegression as LR

model=LR()

model.fit(train_X, train_y)

linearpred=model.predict(test_X)

# %%
model.score(test_X,test_y)
# Out:
# 0.7640461495164271

# %%
# model=LR()

# model.fit(train_X_norm, train_y)

# linearpred=model.predict(test_X_norm)
# model.score(test_X_norm,test_y)

# %%
predcheck=pd.concat([test_X,(model.predict(test_X)-test_y)],axis=1)
predcheck[abs(predcheck.value)>100000]
# Out:
#        access0  years        lat         lng  room  L  D  K  S  bfloor  \
# 25951      6.0     14  35.668518  139.731934     5  1  1  1  0       1
# 19004      6.0      0  35.697377  139.734574     2  1  1  1  0       4
# 5093       8.0      1  35.651816  139.741531     2  1  1  1  1       9
# 18461      8.0     20  35.663569  139.700565     2  1  1  1  0      12
# 13540      9.0     11  35.648915  139.735186     2  1  1  1  0       3
# 11909      6.0     21  35.659703  139.785018     2  1  1  1  1      40
# 16117      5.0     11  35.692625  139.687409     3  1  1  1  0      42
# 7932      12.0     11  35.582189  139.711030     3  1  1  1  0       2
# 27868      6.0     29  35.671961  139.801416     2  1  1  1  1       7
# 2266       9.0     34  35.659836  139.710923     2  1  1  1  1       5
# 28477     12.0      9  35.689620  139.648955     4  1  1  1  0       2
# 19756     15.0      1  35.656721  139.713507     2  1  1  1  0       1
# 11846      7.0      0  35.686579  139.778308     3  1  1  1  0       5
# 24173      3.0     15  35.686153  139.736463     2  1  1  1  1      12
# 17516      4.0      4  35.669206  139.682842     3  1  1  1  0       3
# 12832      5.0      5  35.690376  139.744127     1  1  1  1  1       6
# 8559       5.0     11  35.692625  139.687409     3  1  1  1  0      42
# 17458      2.0     12  35.687056  139.741572     2  1  1  1  1       3
# 14845      9.0      0  35.670381  139.711063     1  1  1  1  0       3
# 22693      2.0      7  35.695902  139.708295     2  1  1  1  0      29
# 5073       1.0     16  35.608448  139.749191     1  0  0  1  0      29
# 22685      5.0     28  35.631612  139.689223     3  1  1  1  0       2
# 3740       7.0      5  35.648772  139.726246     3  1  1  1  0       3
# 2162      10.0     30  35.664692  139.692214     2  1  1  1  0       1
# 22685  1.328363e+05
# 3740  -1.411270e+05
# 2162   1.115175e+05
# 21819 -1.258708e+05
# 27695 -1.305018e+05
# 16520 -4.697195e+05
# 29209 -1.099630e+05
# 18308 -1.551802e+05
# 31014 -1.582936e+05
# 3618   1.403975e+05
# 9237  -3.165898e+05
# 14453  1.323018e+05
# 7974  -1.229489e+05
# 3819   1.405007e+05
# 13498 -5.096975e+05
# 20245 -2.079915e+05
# 1940  -3.804622e+05
# 23673 -1.651265e+05
# 14268  1.162620e+05
# 30677 -1.272021e+05
# 12978 -1.565024e+05
# 12863 -2.378282e+05
# 4456  -1.376840e+05
# 24024 -1.053138e+05
# 24376  1.223690e+05
# 27176  1.347177e+05
# 2388   1.390214e+05
# 27157 -1.312812e+05
# 16241  1.223292e+05
# 411    1.316868e+05
# 2727  -1.492549e+05
# 3146  -1.321904e+05
# 21367  1.001389e+05
#
# [54 rows x 47 columns]

# %%
# for i in train_tmp.index:
#     if i.index in list(predcheck[abs(predcheck.value)>100000].index) :
#         print(train_tmp[])
# predcheck2=pd.concat([test_tmp,test_y],axis=1)
# predcheck2.ix[list(predcheck[abs(predcheck.value)>100000].index), :]

import pandas as pd
train = pd.read_csv('train.csv', delimiter=',',engine='python')
test = pd.read_csv('test.csv',delimiter=',', engine='python')

train_tmp = train.copy()
test_tmp = test.copy()
# train_tmp = train_tmp.drop("賃料", axis=1)
df = pd.concat([train_tmp, test_tmp])
df=df.reset_index(drop=True)
len(df)

# df = pd.concat([train_tmp, test_tmp])
# df=df.reset_index(drop=True)
# len(df)
# df.ix[list(predcheck[abs(predcheck.value)>100000].index)]
df
# Out:
#           id                                               アクセス  \
# 0          1  都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...
# 1          2  都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...
# 2          3  京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...
# 3          4  総武線・中央線（各停）\t高円寺駅\t徒歩9分\t\t丸ノ内線(池袋－荻窪)\t新高円寺駅\...
# 4          5  京成金町線\t京成金町駅\t徒歩5分\t\t常磐線\t金町(東京都)駅\t徒歩7分\t\t京...
# 5          6  常磐線快速\t南千住駅\t徒歩2分\t\t都電荒川線\t三ノ輪橋駅\t徒歩10分\t\t日比...
# 6          7  西武池袋線\t大泉学園駅\t徒歩4分\t\t西武池袋線\t保谷駅\t徒歩25分\t\t東武東...
# 7          8  東急東横線\t学芸大学駅\t徒歩7分\t\t東急東横線\t都立大学駅\t徒歩16分\t\t東...
# 8          9  南北線\t東大前駅\t徒歩3分\t\t都営三田線\t白山(東京都)駅\t徒歩10分\t\t千...
# 9         10  埼京線\t板橋駅\t徒歩8分\t\t都営三田線\t新板橋駅\t徒歩4分\t\t東武東上線\t...
# 10        11  都営浅草線\t西馬込駅\t徒歩4分\t\t都営浅草線\t馬込駅\t徒歩16分\t\t東急池上...
# 62720  【コンビニ】 104m\t【コンビニ】 309m\t【スーパー】 383m\t【スーパー】 ...
# 62721  【飲食店】 460m\t【コンビニ】 410m\t【コンビニ】 257m\t【ドラッグストア...
# 62722                                                NaN
# 62723                                                NaN
# 62724  【スーパー】 283m\t【スーパー】 839m\t【コンビニ】 322m\t【コンビニ】 ...
# 62725                                                NaN
# 62726  【スーパー】 523m\t【スーパー】 696m\t【コンビニ】 381m\t【ドラッグスト...
# 62727  【コンビニ】 204m\t【スーパー】 284m\t【スーパー】 496m\t【コンビニ】 ...
# 62728                                                NaN
# 62729                                                NaN
# 62730                                                NaN
# 62731                                                NaN
#
#                          契約期間  \
# 0                         2年間
# 1                         2年間
# 2                         2年間
# 3      2年間\t※この物件は\t定期借家\tです。
# 4                         2年間
# 5                         2年間
# 6                         2年間
# 7                         2年間
# 8                         2年間
# 9                         2年間
# 10                        2年間
# 11                        NaN
# 12                        NaN
# 13                        2年間
# 14                        1年間
# 15                        2年間
# 16                        2年間
# 17                        2年間
# 18                        2年間
# 19                        2年間
# 20                        2年間
# 21                        2年間
# 22                        NaN
# 23                        2年間
# 24                        2年間
# 25                        2年間
# 26                        2年間
# 27                        2年間
# 28                        2年間
# 29                        2年間
# ...                       ...
# 62702                     NaN
# 62703                     2年間
# 62704                     2年間
# 62705                     2年間
# 62706                     2年間
# 62707                     2年間
# 62708                     2年間
# 62709                     2年間
# 62710                     2年間
# 62711                     2年間
# 62712                     NaN
# 62713                     2年間
# 62714                     2年間
# 62715                     2年間
# 62716                     2年間
# 62717                     2年間
# 62718                     NaN
# 62719                     2年間
# 62720                     NaN
# 62721                     2年間
# 62722                     2年間
# 62723                     NaN
# 62724                     NaN
# 62725                     NaN
# 62726                     NaN
# 62727                     2年間
# 62728                     NaN
# 62729  2年間\t※この物件は\t定期借家\tです。
# 62730                     NaN
# 62731                     NaN
#
#                                                     室内設備             建物構造  \
# 0      エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\t敷...     RC（鉄筋コンクリート）
# 1      エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\t敷...              鉄骨造
# 2      エアコン付\tウォークインクローゼット\tシューズボックス／\tバルコニー／\tフローリング...     RC（鉄筋コンクリート）
# 3      エアコン付\tシューズボックス／\tバルコニー／\t2面採光／\t室内洗濯機置場／\tエレベ...     RC（鉄筋コンクリート）
# 4                    バルコニー／\tフローリング／\t室内洗濯機置場\t公営水道／\t下水               木造
# 5      エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...     RC（鉄筋コンクリート）
# 6      エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...     RC（鉄筋コンクリート）
# 7      エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...     RC（鉄筋コンクリート）
# 8           エアコン付\tバルコニー／\tフローリング／\t室内洗濯機置場\t公営水道／\t都市ガス  SRC（鉄骨鉄筋コンクリート）
# 9           エアコン付\tバルコニー／\tフローリング／\t室内洗濯機置場\t公営水道／\t都市ガス              鉄骨造
# 10     エアコン付\tシューズボックス／\tフローリング／\t室内洗濯機置場／\t敷地内ごみ置き場\...     RC（鉄筋コンクリート）
# 11                                                   NaN               木造
# 12     エアコン付\tウォークインクローゼット\tシューズボックス／\tバルコニー／\tフローリング...     RC（鉄筋コンクリート）
# 13            エアコン付\tシューズボックス／\tバルコニー\t水道その他／\t下水／\t都市ガス     RC（鉄筋コンクリート）
# 14     冷房／\tエアコン付\tシューズボックス／\tバルコニー／\t24時間換気システム\t／\t...  SRC（鉄骨鉄筋コンクリート）
# 15     エアコン付\tシューズボックス／\tバルコニー／\t2面採光／\tクッションフロア／\t室内...     RC（鉄筋コンクリート）
# 16     エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\
エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...     RC（鉄筋コンクリート）
# 62717   エアコン付\tシューズボックス／\t出窓／\t室内洗濯機置場\t公営水道／\t下水／\t都市ガス               木造
# 62718                      エアコン付\tフローリング／\t室内洗濯機置場\t都市ガス             軽量鉄骨
# 62719  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気システム\...     RC（鉄筋コンクリート）
# 62720  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t2面採光／\t室内洗濯...     RC（鉄筋コンクリート）
# 62721  エアコン付\tシューズボックス／\tバルコニー／\t室内洗濯機置場／\tエレベーター\t公営...     RC（鉄筋コンクリート）
# 62722     エアコン付\tバルコニー／\tフローリング／\t室内洗濯機置場／\tエレベーター\t都市ガス     RC（鉄筋コンクリート）
# 62723  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...     RC（鉄筋コンクリート）
# 62724  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...     RC（鉄筋コンクリート）
# 62725         エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場              鉄骨造
# 62726  冷房／\tエアコン付\t床下収納\tシューズボックス／\tバルコニー／\tフローリング／\t...               木造
# 62727  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\t敷...     RC（鉄筋コンクリート）
# 62728  冷房／\tエアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t24時間換気...     RC（鉄筋コンクリート）
# 62729  エアコン付／\t床暖房\tフローリング／\t室内洗濯機置場／\t敷地内ごみ置き場\t／\tエ...     RC（鉄筋コンクリート）
# 62730  冷房／\tエアコン付／\t床暖房\tバルコニー／\tフローリング／\t24時間換気システム\...  SRC（鉄骨鉄筋コンクリート）
# 62731  エアコン付\tシューズボックス／\tバルコニー／\tフローリング／\t室内洗濯機置場／\tエ...     RC（鉄筋コンクリート）
#
#                       所在地       所在階  \
# 0             東京都北区滝野川３丁目   1階／12階建
# 1             東京都中央区月島３丁目   5階／10階建
# 2             東京都渋谷区笹塚２丁目  12階／15階建
# 3       東京都杉並区高円寺南２丁目23-2    3階／4階建
# 4          東京都葛飾区金町３丁目7-2    1階／2階建
# 5            東京都荒川区南千住５丁目   6階／12階建
# 6            東京都練馬区東大泉３丁目    6階／8階建
# 7             東京都目黒区鷹番１丁目    1階／6階建
# 8             東京都文京区向丘１丁目    4階／9階建
# 9             東京都板橋区板橋４丁目    2階／3階建
# 10       東京都大田区西馬込１丁目30-8    1階／6階建
# 11          東京都江戸川区北小岩３丁目    1階／2階建
# 12            東京都港区南青山６丁目   6階／10階建
# 13       東京都杉並区阿佐谷南３丁目６－５    3階／3階建
# 14             東京都墨田区緑４丁目   4階／11階建
# 15       東京都渋谷区幡ヶ谷３丁目39-4    4階／5階建
# 16       東京都板橋区桜川３丁目10-12    2階／5階建
# 17          東京都江戸川区西瑞江４丁目    1階／2階建
# 18            東京都新宿区四谷三栄町   5階／11階建
# 19       東京都中央区日本橋箱崎町27-9   8階／12階建
# 20           東京都中野区江古田４丁目       2階建
# 21            東京都文京区湯島２丁目   7階／10階建
# 22             東京都中央区佃１丁目  10階／42階建
# 23           東京都大田区大森西１丁目    4階／5階建
# 24     東京都江戸川区北小岩４丁目３８－２８    2階／4階建
# 25        東京都豊島区千早４丁目32-3    1階／2階建
# 26         東京都台東区台東３丁目3-1  12階／12階建
# 27            東京都足立区綾瀬６丁目    2階／2階建
# 28           東京都江戸川区船堀４丁目  10階／10階建
# 29            東京都渋谷区上原２丁目   1階／10階建
# ...                   ...       ...
# 62702         東京都墨田区本所１丁目    4階／9階建
# 4       74000.0   2DK  39.66m2
# 5      160000.0  2LDK   50.8m2
# 6       78500.0    1K  23.82m2
# 7      115000.0    1K  32.32m2
# 8      184327.0   2DK  65.59m2
# 9       76000.0   1DK   30.3m2
# 10     105000.0    1K  25.81m2
# 11      53000.0    1K   23.1m2
# 12     200000.0  1LDK  37.53m2
# 13     107000.0   2DK   41.5m2
# 14      63000.0    1K  17.73m2
# 15      92000.0   1DK  32.84m2
# 16      87000.0    1K  25.93m2
# 17      68000.0    1K  25.82m2
# 18     310000.0  3LDK  70.82m2
# 19     165000.0   3DK  57.71m2
# 20     130000.0  2LDK  59.62m2
# 21      84000.0    1K  21.06m2
# 22     346000.0  2LDK   81.2m2
# 23      80000.0    1K  22.98m2
# 24      45000.0    1R  15.48m2
# 25      62000.0    1R   11.7m2
# 26     186000.0  1LDK   41.6m2
# 27      47000.0    1K     14m2
# 28     129000.0  1LDK  46.21m2
# 29     129000.0    1R  31.21m2
# ...         ...   ...      ...
# 62702       NaN    1K  25.86m2
# 62703       NaN    1K  35.62m2
# 62704       NaN    1R  24.13m2
# 62705       NaN    1K  27.98m2
# 62706       NaN    1K  26.51m2
# 62707       NaN   2DK  55.31m2
# 62708       NaN  2LDK   53.5m2
# 62709       NaN    1R  27.37m2
# 62710       NaN   2DK     42m2
# 62711       NaN    1K  29.87m2
# 62712       NaN   1DK     26m2
# 62713       NaN  2LDK  44.62m2
# 62714       NaN    1R     25m2
# 62715       NaN    1R   30.3m2
# 62716       NaN  2LDK  58.09m2
# 62717       NaN    1K   18.9m2
# 62718       NaN    1K  20.03m2
# 62719       NaN   1DK  28.38m2
# 62720       NaN   1DK  30.67m2
# 62721       NaN   2DK  46.85m2
# 62722       NaN    1K  25.73m2
# 62723       NaN  1LDK  40.85m2
# 62724       NaN  1LDK  37.45m2
# 62725       NaN    1K  29.81m2
# 62726       NaN  2LDK  66.37m2
# 62727       NaN    1K  25.66m2
# 62728       NaN    1R  22.71m2
# 62729       NaN  1LDK  45.76m2
# 62730       NaN    1K   55.2m2
# 62731       NaN    1K  21.18m2
#
#                                                      駐車場
# 0                                                駐輪場\t空有
# 1                             駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# 2      駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t30,000円(税込)\t距離100m
# 3                              駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 4        駐車場\t近隣\t17,000円(税込)\t距離300m\t駐輪場\t無\tバイク置き場\t無
# 5       駐輪場\t空有\t駐車場\t近隣\t27,000円(税込)\t距離150m\tバイク置き場\t無
# 6       駐輪場\t空有\t駐車場\t近隣\t16,000円(税込)\t距離200m\tバイク置き場\t無
# 7                                                    NaN
# 8                                                 駐車場\t無
# 9                                                 駐車場\t無
# 10             駐車場\t空有\t32,400円(税込)\t駐輪場\t空有\tバイク置き場\t空有
# 11                                                   NaN
# 12                                                   NaN
# 13                                     駐輪場\t無\tバイク置き場\t無
# 14                                    駐輪場\t空有\tバイク置き場\t無
# 15       駐車場\t近隣\t27,000円(税込)\t距離500m\t駐輪場\t無\tバイク置き場\t無
# 16         駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t23,000円\t距離150m
# 17                              駐車場\t近隣\t15,120円\t距離200m
# 18                                               駐輪場\t空有
# 19                             駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 20              駐車場\t空有\t0円\t駐輪場\t空有\t0円\tバイク置き場\t空有\t0円
# 21                                               駐輪場\t空有
# 22                                               駐輪場\t空有
# 23      駐輪場\t空有\t駐車場\t近隣\t25,000円(税込)\t距離100m\tバイク置き場\t無
# 24                   駐車場\t空有(1台)\t10,000円\t距離0m\t(小型車のみ)
# 25                                           駐輪場\t空有\t0円
# 26      駐輪場\t空有\t駐車場\t近隣\t37,800円(税込)\t距離300m\tバイク置き場\t無
# 27                                    駐輪場\t空有\tバイク置き場\t無
# 28                                     駐輪場\t無\tバイク置き場\t無
# 29                            駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# ...                                                  ...
# 62702                                                NaN
# 62703   駐輪場\t空有\t駐車場\t近隣\t35,000円(税込)\t距離300m\tバイク置き場\t無
# 62704           駐車場\t空有\t35,000円(税込)\t駐輪場\t空有\tバイク置き場\t無
# 62705                                             駐車場\t無
# 62706  駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t12,960円(税込)\t距離300m
# 62707                                駐輪場\t空有\tバイク置き場\t空有
# 62708                         駐輪場\t空有\t駐車場\t無\tバイク置き場\t無
# 62709                        駐輪場\t空有\tバイク置き場\t空有\t駐車場\t無
# 62710       駐輪場\t空有\t駐車場\t近隣\t20,000円\t距離250m\tバイク置き場\t無
# 62711                                            駐輪場\t空有
# 62712                                                NaN
# 62713      駐輪場\t空有\tバイク置き場\t空有\t駐車場\t近隣\t13,000円\t距離200m
# 62714                                                NaN
# 62715                                                NaN
# 62716                  駐輪場\t空有\t駐車場\t近隣\t28,000円\t距離150m
# 62717                                  駐輪場\t無\tバイク置き場\t無
# 62718                                                NaN
# 62719   駐輪場\t空有\t駐車場\t近隣\t21,600円(税込)\t距離300m\tバイク置き場\t無
# 62720   駐輪場\t空有\t駐車場\t近隣\t37,800円(税込)\t距離300m\tバイク置き場\t無
# 62721                                            駐輪場\t空有
# 62722                                             駐車場\t無
# 62723                                            駐輪場\t空有
# 62724                           駐車場\t近隣\t30,000円\t距離400m
# 62725                                                NaN
# 62726                           駐車場\t近隣\t30,000円\t距離400m
# 62727                          駐車場\t無\t駐輪場\t無\tバイク置き場\t無
# 62728                          駐車場\t空有\t43,200円\t駐輪場\t空有
# 62729           駐車場\t空有\t32,400円(税込)\t駐輪場\t空有\tバイク置き場\t無
# 62730                                            駐輪場\t空有
# 62731                                                NaN
#
# [62732 rows x 17 columns]

# %%
# calc
import scipy.stats as st
import scipy
data=scipy.stats.zscore(test_y-linearpred)
n=len(data)
m=n+1
ii=np.arange(n)+1 # i=1~n

qo=np.sort(data)
qp=st.norm.ppf( ii/m )



# plot
plt.plot([-3,3],[-3,3])
plt.plot(qo,qp,'r*')
plt.xlabel('Observed Quartile')
plt.ylabel('Predicted Quartile')
plt.savefig('qqplot.png',dpi=300)

# %% [markdown]
# ## ランダムフォレストで学習

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
 

rg = RFR(n_jobs=-1, random_state=2525)
 
rg.fit(train_X,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#                       oob_score=False, random_state=2525, verbose=0,
#                       warm_start=False)

# %%
rg.score(test_X,test_y)
# Out:
# 0.9235355457196426

# %%
# X.ix[[20926]].drop([ 'address_世田谷', 'address_中央', 'address_中野',
#        'address_北', 'address_千代田', 'address_台東', 'address_品川', 'address_墨田',
#        'address_大田', 'address_文京', 'address_新宿', 'address_杉並', 'address_板橋',
#        'address_江戸川', 'address_江東', 'address_渋谷', 'address_港', 'address_目黒',
#        'address_練馬', 'address_荒川', 'address_葛飾', 'address_豊島', 'address_足立' ],axis=1)

# %%
# df.ix[[20926]]

# %%
predcheck=pd.concat([test_X,(rg.predict(test_X)-test_y)],axis=1)
misslist=list(predcheck[abs(predcheck.value)>500000].index)
df.ix[list(predcheck[abs(predcheck.value)>500000].index)].head()
# Out:
#         id                                               アクセス  \
# 5093  5094  南北線\t麻布十番駅\t徒歩8分\t\t都営大江戸線\t赤羽橋駅\t徒歩9分\t\t山手線\...
#
#                                                    キッチン  \
# 5093  IHコンロ\t／\tコンロ3口／\tシステムキッチン\t／\tカウンターキッチン\t／\tL...
#
#                                                  バス・トイレ  \
# 5093  専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t追焚機能／\t浴室乾燥機\t...
#
#                                                    周辺環境  \
# 5093  【飲食店】 959m\t【飲食店】 611m\t【スーパー】 417m\t【スーパー】 65...
#
#                         契約期間  \
# 5093  3年間\t※この物件は\t定期借家\tです。
#
#                                                    室内設備          建物構造  \
# 5093  エアコン付／\t床暖房\tウォークインクローゼット\tシューズボックス／\tバルコニー／\t...  RC（鉄筋コンクリート）
#
#                 所在地           所在階      放送・通信 方角    築年数         賃料         間取り  \
# 5093  東京都港区三田２丁目4-3  9階／9階建（地下2階）  インターネット対応  西  1年8ヶ月  2500000.0  2LDK+S(納戸)
#
#             面積                    駐車場
# 5093  217.29m2  駐車場\t空有(43台)\t48,600円

# %%
# rg.predict(X.ix[misslist])
# オリジナルは11万円
# X.ix[misslist]
# misslist
# rg.predict(X.ix[[20926]])

# %%
# df.ix[misslist]

# %%
# rg.predict(test_X[test_X.index==9564] )

# %%
checktesty=test_y.sort_values()
checktestX=test_X.ix[list(checktesty.index)]
checktesty=checktesty.reset_index(drop=True)#これと

checkpred=pd.DataFrame(rg.predict(checktestX))#これ
# checktesty.plot()
# checkpred.plot()

# %%
check=pd.concat([checktesty,checkpred], axis=1)
check.columns=["actual","predict"]
# checktesty
check.plot(alpha=0.5)

# %%
fti = rg.feature_importances_

print('Feature Importances:')
for i,feat in enumerate(test_X.columns):
    print('\t{0:10s} : {1:>.6f}'.format(feat, fti[i]))
# Out:
# Feature Importances:
# 	access0    : 0.012098
# 	years      : 0.052287
# 	lat        : 0.061248
# 	lng        : 0.044225
# 	room       : 0.002025
# 	L          : 0.325071
# 	D          : 0.000301
# 	K          : 0.000331
# 	S          : 0.002813
# 	bfloor     : 0.010741
# 	height     : 0.078194
# 	width      : 0.315297
# 	architect  : 0.000952
# 	direction  : 0.001574
# 	sharetoilet : 0.000034
# 	ih         : 0.001243
# 	gas        : 0.000672
# 	wm         : 0.000633
# 	pa         : 0.000705
# 	ms         : 0.001265
# 	one        : 0.000392
# 	air        : 0.000513
# 	rp         : 0.011017
# 	address1_世田谷 : 0.000922
# 	address1_中央 : 0.000314
# 	address1_中野 : 0.000116
# 	address1_北 : 0.000264
# 	address1_千代田 : 0.001804
# 	address1_台東 : 0.000185
# 	address1_品川 : 0.000722
# 	address1_墨田 : 0.000144
# 	address1_大田 : 0.000325
# 	address1_文京 : 0.001209
# 	address1_新宿 : 0.000312
# 	address1_杉並 : 0.000120
# 	address1_板橋 : 0.000088
# 	address1_江戸川 : 0.000131
# 	address1_江東 : 0.000131
# 	address1_渋谷 : 0.008847
# 	address1_港 : 0.054979
# 	address1_目黒 : 0.003854
# 	address1_練馬 : 0.000176
# 	address1_荒川 : 0.000179
# 	address1_葛飾 : 0.000064
# 	address1_豊島 : 0.001242
# 	address1_足立 : 0.000243

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(rg, X, y)
# 各分割におけるスコア
print('Cross-Validation scores: {}'.format(scores))
# スコアの平均値
import numpy as np

import numpy as np
print('Average score: {}'.format(np.mean(scores)))
# Out:
# Cross-Validation scores: [0.90748403 0.91434755 0.93344586]
# Average score: 0.9184258125033699

# %% [markdown]
# # グリッドサーチ

# %%
# # 必要なライブラリのインポート

# # 動かすパラメータを明示的に表示、今回は決定木の数を変えてみる
# params = {'n_estimators'  : [3, 10, 100, 1000, 10000], 'n_jobs': [-1]}

# %%
# # モデルにインスタンス生成
# rg = RFR(n_jobs=-1, random_state=2525)
# # ハイパーパラメータ探索
# cv = GridSearchCV(rg, params, cv = 10, scoring= 'neg_mean_squared_error', n_jobs =1)
# cv.fit(train_X, train_y)

# %% [markdown]
# # optuna

# %%
# import optuna
# from sklearn.ensemble import RandomForestRegressor
 
# def objective(trial):
#     '''
#     trial:set of hyperparameter    
#     '''
#     # hypyer param
#     max_depth = trial.suggest_int('max_depth', 3, 10) # 深すぎると過学習になるかも...
#     n_estimators = trial.suggest_int('n_estimators', 50, 100) # しっかりやるなら100以上
#     max_features = trial.suggest_categorical('max_features', ['sqrt', 'auto', 'log2'])
 
#     # model
#     model = RFR(max_depth=max_depth,
#                                   n_estimators=n_estimators,
#                                   max_features=max_features,
#                                   n_jobs=-1,
#                                   verbose=1)
 
#     # fit
#     model.fit(train_X, train_y)
 
#     # eval
#     score = -1 * model.score(test_X,test_y) 
#     return score

# %%
# # # %%time
 
# study = optuna.create_study()
 
# # https://optuna.readthedocs.io/en/stable/reference/study.html#optuna.study.Study.optimize
# study.optimize(func=objective, # 実行する関数
#                n_trials=30, # 試行回数
#                timeout=None, # 与えられた秒数後に学習を中止します。default=None
#                n_jobs=-1 # 並列実行するjob数
#               )

# %%
# #最適化したハイパーパラメータの確認
# print('check!!!')
# print('best_param:{}'.format(study.best_params))
# print('====================')
 
# #最適化後の目的関数値
# print('best_value:{}'.format(study.best_value))
# print('====================')
 
# #最適な試行
# print('best_trial:{}'.format(study.best_trial))
# print('====================')
 
# # トライアルごとの結果を確認
# for i in study.trials:
#     print('param:{0}, eval_value:{1}'.format(i[5], i[2]))
# print('====================')

# %% [markdown]
# # Borutaの実行

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestRegressor
 
# model
rgb = RFR(n_jobs=-1, random_state=2525,max_depth= 10, n_estimators=70, max_features='auto')
 
# define Boruta feature selection method
# https://github.com/scikit-learn-contrib/boruta_py/blob/master/boruta/boruta_py.py
feat_selector = BorutaPy(rg, 
                         n_estimators='auto',  # 特徴量の数に比例して、木の本数を増やす
                         verbose=2, # 0: no output,1: displays iteration number,2: which features have been selected already
                         alpha=0.05, # 有意水準
                         max_iter=50, # 試行回数
                         random_state=1
                        )
 
# 実行!!
feat_selector.fit(train_X.as_matrix(),train_y)
train_X_selected = train_X.iloc[:,feat_selector.support_]
test_X_selected = test_X.iloc[:,feat_selector.support_]
print( train_X_selected.columns)
rgb = RFR(n_jobs=-1, random_state=2525,max_depth= 10, n_estimators=70, max_features='auto')
 
rgb.fit(train_X_selected,train_y)

print(rgb.score(train_X_selected,train_y))
# Out:
# Iteration: 	1 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	2 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	3 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	4 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	5 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	6 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	7 / 50
# Confirmed: 	0
# Tentative: 	46
# Rejected: 	0
# Iteration: 	8 / 50
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	33
# Iteration: 	9 / 50
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	33
# Iteration: 	10 / 50
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	33
# Iteration: 	11 / 50
# Confirmed: 	10
# Tentative: 	3
# Rejected: 	33
# Iteration: 	12 / 50
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	34
# Iteration: 	13 / 50
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	34
# Iteration: 	14 / 50
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	34
# Iteration: 	15 / 50
# Confirmed: 	11
# Tentative: 	1
# Rejected: 	34
# Iteration: 	16 / 50
# Confirmed: 	11
# Tentative: 	0
# Rejected: 	35
#
#
# BorutaPy finished running.
#
# Iteration: 	17 / 50
# Confirmed: 	11
# Tentative: 	0
# Rejected: 	35
# Index(['access0', 'years', 'lat', 'lng', 'L', 'bfloor', 'height', 'width',
#        'rp', 'address1_渋谷', 'address1_港'],
#       dtype='object')
# 0.955662233153799

# %%
from sklearn.model_selection import cross_val_score
X_selected=X.iloc[:,feat_selector.support_]
scores = cross_val_score(rgb, X_selected, y)
# 各分割におけるスコア
print('Cross-Validation scores: {}'.format(scores))
# スコアの平均値
import numpy as np

import numpy as np
print('Average score: {}'.format(np.mean(scores)))
# Out:
# Cross-Validation scores: [0.89430125 0.89757693 0.91107578]
# Average score: 0.9009846545985433

# %%
checktesty=test_y.sort_values()
checktestX=test_X_selected.ix[list(checktesty.index)]
checktesty=checktesty.reset_index(drop=True)#これと

checkpred=pd.DataFrame(rgb.predict(checktestX))#これ
# checktesty.plot()
# checkpred.plot()
check=pd.concat([checktesty,checkpred], axis=1)
check.columns=["actual","predict"]
# checktesty
check.plot(alpha=0.5)

# %% [markdown]
# # lightGBM

# %%
# import lightgbm as lgb
# train_data_set = lgb.Dataset(train_X, train_y)
# test_data_set = lgb.Dataset(test_X, test_y, reference=train_data_set)
 
# params = {                                                                                               
#     'boosting_type': 'gbdt',                                                                             
#     'objective': 'regression_l2',                                                                           
#     'metric': 'l2',                                                                             
#     'num_leaves': 40,                                                                                    
#     'learning_rate': 0.05,                                                                               
#     'feature_fraction': 0.9,                                                                             
#     'bagging_fraction': 0.8,                                                                             
#     'bagging_freq': 5,   
#     'lambda_l2': 2,
# }                                                                                                        
                                                                                                         
# gbm = lgb.train(params,                                                                                  
#                 train_data_set,                                                                               
#                 num_boost_round=200,                                                                      
#                 valid_sets=test_data_set,                                                                     
#                 early_stopping_rounds=10
#                 )
# Out:
# [1]	valid_0's l2: 4.5241e+09
# Training until validation scores don't improve for 10 rounds.
# [2]	valid_0's l2: 4.1949e+09
# [3]	valid_0's l2: 3.88851e+09
# [4]	valid_0's l2: 3.60444e+09
# [5]	valid_0's l2: 3.36389e+09
# [6]	valid_0's l2: 3.12592e+09
# [7]	valid_0's l2: 2.90525e+09
# [8]	valid_0's l2: 2.71011e+09
# [9]	valid_0's l2: 2.52508e+09
# [10]	valid_0's l2: 2.35704e+09
# [11]	valid_0's l2: 2.20305e+09
# [12]	valid_0's l2: 2.0655e+09
# [13]	valid_0's l2: 1.93781e+09
# [14]	valid_0's l2: 1.82158e+09
# [15]	valid_0's l2: 1.71671e+09
# [16]	valid_0's l2: 1.61477e+09
# [17]	valid_0's l2: 1.52204e+09
# [18]	valid_0's l2: 1.44313e+09
# [19]	valid_0's l2: 1.36622e+09
# [20]	valid_0's l2: 1.29919e+09
# [21]	valid_0's l2: 1.23668e+09
# [22]	valid_0's l2: 1.17777e+09
# [23]	valid_0's l2: 1.11929e+09
# [24]	valid_0's l2: 1.06928e+09
# [25]	valid_0's l2: 1.02503e+09
# [26]	valid_0's l2: 9.78234e+08
# [27]	valid_0's l2: 9.36138e+08
# [28]	valid_0's l2: 8.95864e+08
# [29]	valid_0's l2: 8.6029e+08
# [30]	valid_0's l2: 8.29038e+08
# [31]	valid_0's l2: 7.97242e+08
# [32]	valid_0's l2: 7.68653e+08
# [33]	valid_0's l2: 7.42505e+08
# [34]	valid_0's l2: 7.1974e+08
# [35]	valid_0's l2: 7.00521e+08
# [36]	valid_0's l2: 6.77317e+08
# [37]	valid_0's l2: 6.57721e+08
# [38]	valid_0's l2: 6.38929e+08
# [39]	valid_0's l2: 6.22517e+08
# [181]	valid_0's l2: 3.17104e+08
# [182]	valid_0's l2: 3.16899e+08
# [183]	valid_0's l2: 3.16804e+08
# [184]	valid_0's l2: 3.16835e+08
# [185]	valid_0's l2: 3.16677e+08
# [186]	valid_0's l2: 3.16724e+08
# [187]	valid_0's l2: 3.16023e+08
# [188]	valid_0's l2: 3.16047e+08
# [189]	valid_0's l2: 3.15235e+08
# [190]	valid_0's l2: 3.14769e+08
# [191]	valid_0's l2: 3.14515e+08
# [192]	valid_0's l2: 3.14371e+08
# [193]	valid_0's l2: 3.1422e+08
# [194]	valid_0's l2: 3.13985e+08
# [195]	valid_0's l2: 3.13487e+08
# [196]	valid_0's l2: 3.13408e+08
# [197]	valid_0's l2: 3.13237e+08
# [198]	valid_0's l2: 3.11877e+08
# [199]	valid_0's l2: 3.12007e+08
# [200]	valid_0's l2: 3.1196e+08
# Did not meet early stopping. Best iteration is:
# [198]	valid_0's l2: 3.11877e+08

# %%
# y_pred=gbm.predict(test_X,num_iteration=gbm.best_iteration)

# %%
# from sklearn.metrics import r2_score
# r2_score(test_y,y_pred)
# Out:
# 0.9362783927846863

# %% [markdown]
# # SVC(非推奨)

# %%
# from sklearn.svm import SVR
# from sklearn.model_selection import GridSearchCV
# # 学習を行う
# svr = SVR(kernel='rbf')
# svr.fit(train_X, train_y)

# svr.score(test_X,test_y)

# %%
# y_pred=svr.predict(test_X)
# r2_score(test_y,y_pred)

# %%
from sklearn.metrics import mean_squared_error
print("randomforest :"+str(np.sqrt(mean_squared_error(test_y,rg.predict(test_X)))) )
print("randomboruta:"+str(np.sqrt(mean_squared_error(test_y,rg.predict(test_X)))) )
# print("linearpred      :"+str(np.sqrt(mean_squared_error(test_y,model.predict(test_X)))) )
# print("lightgbm        :"+str(np.sqrt(mean_squared_error(test_y,gbm.predict(test_X,num_iteration=gbm.best_iteration)))) )
# print("svm               :"+str(np.sqrt(mean_squared_error(test_y,svr.predict(test_X)))) )
# Out:
# randomforest:22442.71593126777

# %%
#  df_tofile

# %%
X = pd.get_dummies(df_tofile)

# %%
subtrain_X=X.dropna().drop("value",axis=1)

subtrain_y=X.dropna().value

subtest_X=X[X.isnull().any(axis=1)].drop("value",axis=1)

# %%
len(subtrain_X)
# Out:
# 31468

# %%
len(subtest_X)
# Out:
# 31262

# %%
rg = RFR(n_jobs=-1, random_state=2525)
rg.fit(subtrain_X,subtrain_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#                       oob_score=False, random_state=2525, verbose=0,
#                       warm_start=False)

# %%
pred=rg.predict(subtest_X)

# %%
sub = pd.DataFrame(pd.read_csv("test.csv")['id'])
sub["value"] = list(pred)
sub.to_csv("submission.csv", index = False)

# %% [markdown]
# ## 特徴量最初
# randomforest:24531.698709995504

# %% [markdown]
# ## loft flooringなし
# randomforest:19863.88476957777

# %% [markdown]
# ## loft、flooringあり
#
# randomforest:21857.176455527297

# %% [markdown]
#     ["id","access0","address","years","room","L","D","K","S","bfloor","height","width","architect","direction","sharetoilet","separatebath","ih","gas","wm","pa","ms","one","air","value"]+"nullcol"
#
# randomforest:27669.215126753577
#
#
#
# randomforest:18165.900691870556
